# %%
clust_center=kmeans.cluster_centers_
clust_center.shape

# %%
import matplotlib.cm as cm
for i in range(0,5):
    no_clusters= i+1
    kmeans = KMeans(n_clusters=no_clusters, random_state=0).fit(X)
    cluster_labels = kmeans.fit_predict(X)
    colors = cm.nipy_spectral(cluster_labels.astype(float) / no_clusters)
    pca=PCA()
    prin_comp=pca.fit_transform(X)
    X_pc1=prin_comp[:,0]
    Y_pc2=prin_comp[:,1]
    
    fig,ax2 = plt.subplots()
    plt.title("Plot with number of clusters=%d" %(no_clusters))
    plt.xlabel('PC1')
    plt.ylabel('PC2')

    ax2.scatter(X_pc1, Y_pc2, marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')
    legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper right", title="Cluster no",prop={'size': 10})

    
    # Labeling the clusters
#     centers = np.matmul(kmeans.cluster_centers_.T,pca.
    
    # Project the centers onto the new space 
    
    
#     # Draw white circles at cluster centers
#     ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
#                 c="white", alpha=1, s=200, edgecolor='k')

#     for i, c in enumerate(centers):
#         ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
#                     s=50, edgecolor='k')
    
    ax2.set_xlabel("PC1")
    ax2.set_ylabel("PC2")
    plt.show()

# %%
# Computing the principal directions to project the data

pca=PCA()
prin_comp=pca.fit_transform(X)
plt.figure(figsize=(8,6))
plt.scatter(prin_comp[:,0],prin_comp[:,1])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("In built PCA solver")


X_pc1=prin_comp[:,0]
Y_pc2=prin_comp[:,1]

Colour_clusters=kmeans.labels_


fig, ax = plt.subplots()


scatter = ax.scatter(X_pc1, Y_pc2, c=Colour_clusters)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper right", title="Clusters",prop={'size': 6})

#ax.add_artist(legend1)

# %%
N = 45
x, y = np.random.rand(2, N)
c = np.random.randint(1, 5, size=N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper right", title="Clusters")

ax.add_artist(legend1)

# %%
# Doing this is hard as first you need to project the cluster centers onto the changed space, then only calculate the centers
# Instead we just assign each sample to a cluster and represent that in the principal component transformed space
# Do this on Tuesday if you have time
i=5;
alpha=ascii_lowercase[0:i]

groups={'A':clust_center(0,0:2)}

for i in range(1,len(alpha))

groups.update(['alpha[i]',clust_center(i,0:2)])

print(groups)

# %%
groups = {'A': (2,2),
          'B': (3,4),
          'C': (4,4),
          'D': (4,1)}
for i in enumerate(groups.keys()):

# %%
N = 45
x, y = np.random.rand(2, N)
c = np.random.randint(1, 5, size=N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper right", title="Clusters")

ax.add_artist(legend1)

# %%
import numpy as np
from matplotlib import pyplot as plt

scatter_x = np.array([1,2,3,4,5])
scatter_y = np.array([5,4,3,2,1])
group = np.array([1,3,2,1,3])
cdict = {1: 'red', 2: 'blue', 3: 'green' }

fig, ax = plt.subplots()
for g in np.unique(group):
    ix = np.where(group == g)
    ax.scatter(scatter_x[ix], scatter_y[ix], c = cdict[g], label = g, s = 100)
ax.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

range_n_clusters = [2, 3, 4, 5, 6,7,8,9,10]

for no_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots()
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (no_clusters + 1) * 10])
    kmeans= KMeans(n_clusters=no_clusters,random_state=0).fit(X)
    cluster_labels = kmeans.fit_predict(X)

    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", no_clusters,
              "The average silhouette_score is :", silhouette_avg)
     # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(no_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / no_clusters)

        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ae3558dda01> in <module>
#       5 for no_clusters in range_n_clusters:
#       6     # Create a subplot with 1 row and 2 columns
# ----> 7     fig, ax1 = plt.subplots()
#       8     fig.set_size_inches(18, 7)
#       9
#
# NameError: name 'plt' is not defined

# %%
 #calculating the heat map which is a matrix which has the dimensions of no of clusters cross the no of unique conditions
# in the metadata datdframe
# for no_clusters in range_n_clusters:
no_clusters=10
conditions=metadata['Study'].unique()

index_matrix=np.zeros((conditions.size,20))


# Matrix_Clusters_Conditions_pd=pd.DataFrame(Matrix_Clusters_Conditions,index=No_clusters, columns=conditions)

for j in range(0,conditions.size):
    k=0
    for i in range(0,cluster_labels.size):
        if metadata.iloc[i,0]==conditions[j]:
            index_matrix[j,k]=i+1
            k+=1


Matrix_Clusters_Conditions=np.zeros((no_clusters,conditions.size))

for l in range(0,conditions.size):
    for m in range(0,20):
        if index_matrix[l,m]!=0:
            for n in range(0,no_clusters):
                if cluster_labels[int(index_matrix[l,m])-1]==(n):
                    Matrix_Clusters_Conditions[n,l]+=1
                    break


Matrix_Clusters_Conditions_Sum=np.sum(Matrix_Clusters_Conditions,axis=0)

# Making into fraction 
for j in range(0,conditions.size):
    Matrix_Clusters_Conditions[:,j]=Matrix_Clusters_Conditions[:,j]/Matrix_Clusters_Conditions_Sum[j]
#transfering the data into a proper dataframe  

Matrix_Clusters_Conditions_pd=pd.DataFrame(Matrix_Clusters_Conditions,columns=conditions)

Matrix_Clusters_Conditions_pd=pd.DataFrame(Matrix_Clusters_Conditions,columns=conditions)
plt.figure(no_clusters)
ax = sns.heatmap(Matrix_Clusters_Conditions_pd)

# %%
Matrix_Clusters_Conditions_pd=pd.DataFrame(Matrix_Clusters_Conditions,columns=conditions)
ax = sns.heatmap(Matrix_Clusters_Conditions_pd)

# %%
# Here essentially we transform from a matrix to a single coloumn vector
Matrix_Clusters_Conditions_pd=pd.DataFrame([],index=np.arange(0,conditions.size*no_clusters),columns=['Cluster','Conditions','Fraction'])
Matrix_Clusters_Conditions_pd['Clusters']  =  Cluster_forheatmap
Matrix_Clusters_Conditions_pd['Conditions'] = Cond_forheatmap
Matrix_Clusters_Conditions_pd['Fraction']=Matrix_Clusters_Conditions_forheatmap                                                                         
                                                                         
# Now presenting the heatmap
Matrix_Clusters_Conditions_pd=Matrix_Clusters_Conditions_pd.pivot("Clusters","Conditions", "Fraction")                                                                         
ax = sns.heatmap(Matrix_Clusters_Conditions_pd)

# %%
Matrix_Clusters_Conditions_forheatmap=Matrix_Clusters_Conditions.reshape(no_clusters+conditions.size,1,order='F)

Cond_forheatmap=np.array(range(1*conditions.size*no_clusters), dtype=object).reshape(conditions.size*no_clusters,1)
for i in range(0,conditions.size*no_clusters):
    Cond_forheatmap[i]=conditions[int(i/no_clusters)]
Cluster_howmany=np.zeros(no_clusters)    
for i in range(0,no_clusters):    
    Cluster_howmany[i]=i    
Cluster_forheatmap=Cluster_howmany                                                                        
                                                                         
for i in range(0,conditions.size-1):
    Cluster_forheatmap=np.concatenate((Cluster_forheatmap,Cluster_howmany))

                                                                
# Here essentially we transform from a matrix to a single coloumn vector
Matrix_Clusters_Conditions_pd=pd.DataFrame([],index=np.arange(0,conditions.size*no_clusters),columns=['Cluster','Conditions','Fraction'])
Matrix_Clusters_Conditions_pd['Cluster']  =  Cluster_forheatmap
Matrix_Clusters_Conditions_pd['Conditions'] = Cond_forheatmap
Matrix_Clusters_Conditions_pd['Fraction']=Matrix_Clusters_Conditions_forheatmap                                                                         
                                                                         
# Now presenting the heatmap
Matrix_Clusters_Conditions_pd=Matrix_Clusters_Conditions_pd.pivot("Cluster", "Conditions", "Fraction")                                                                         
ax = sns.heatmap(Matrix_Clusters_Conditions)
